# %%
import pandas as pd
import random

# %%
# Load the dataset from CSV
df = pd.read_csv("traffic_data.csv")

df.head(14)

# print(df['congestion_level'].value_counts())
# Out:
#    time_of_day day_type weather road_type  vehicle_count  road_lanes  \
# 0      Morning  Weekend   Sunny     Local            154           6
# 1      Morning  Weekend   Sunny   Highway            160           6
# 2        Night  Weekend   Foggy  Mountain             40           3
# 3    Afternoon  Weekday   Sunny     Local             82           3
# 4        Night  Weekday   Foggy   Highway            296           3
# 5      Evening  Weekday   Foggy   Highway             37           4
# 6    Afternoon  Weekend   Sunny   One-way             46           2
# 7      Evening  Weekend   Snowy     Local            245           3
# 8      Evening  Weekday   Rainy   One-way            245           3
# 9      Morning  Weekday   Foggy     Local            178           3
# 10   Afternoon  Weekend   Foggy     Local            280           6
# 11     Evening  Weekday   Rainy  Mountain             70           1
# 12     Evening  Weekend   Snowy   Highway            115           2
# 13     Morning  Weekend   Foggy     Local            284           2
#
#     vehicle_mix_ratio congestion_level
# 0                0.20           Medium
# 1                0.55           Medium
# 2                0.37              Low
# 3                0.58              Low
# 4                0.62             High
# 5                0.25              Low
# 6                0.86              Low
# 7                0.39             High
# 8                0.61             High
# 9                0.34           Medium
# 10               0.71             High
# 11               0.21              Low
# 12               0.68           Medium
# 13               0.38             High

# %%
data = df.copy()

time_map = {
    'Morning': 0,
    'Afternoon': 1,
    'Evening': 2,
    'Night': 3
}

day_map = {
    'Weekday': 0,
    'Weekend': 1
}

weather_map = {
    'Sunny': 0,
    'Rainy': 1,
    'Foggy': 2,
    'Snowy': 3
}

road_map = {
    'Highway': 0,
    'Local': 1,
    'One-way': 2,
    'Mountain': 3
}

congestion_map = {
    'Low': 0,
    'Medium': 1,
    'High': 2
}

# Apply the mappings to each column
data['time_of_day'] = data['time_of_day'].map(time_map)
data['day_type'] = data['day_type'].map(day_map)
data['weather'] = data['weather'].map(weather_map)
data['road_type'] = data['road_type'].map(road_map)
data['congestion_level'] = data['congestion_level'].map(congestion_map)


data.head(14)
# Out:
#     time_of_day  day_type  weather  road_type  vehicle_count  road_lanes  \
# 0             0         1        0          1            154           6
# 1             0         1        0          0            160           6
# 2             3         1        2          3             40           3
# 3             1         0        0          1             82           3
# 4             3         0        2          0            296           3
# 5             2         0        2          0             37           4
# 6             1         1        0          2             46           2
# 7             2         1        3          1            245           3
# 8             2         0        1          2            245           3
# 9             0         0        2          1            178           3
# 10            1         1        2          1            280           6
# 11            2         0        1          3             70           1
# 12            2         1        3          0            115           2
# 13            0         1        2          1            284           2
#
#     vehicle_mix_ratio  congestion_level
# 0                0.20                 1
# 1                0.55                 1
# 2                0.37                 0
# 3                0.58                 0
# 4                0.62                 2
# 5                0.25                 0
# 6                0.86                 0
# 7                0.39                 2
# 8                0.61                 2
# 9                0.34                 1
# 10               0.71                 2
# 11               0.21                 0
# 12               0.68                 1
# 13               0.38                 2
